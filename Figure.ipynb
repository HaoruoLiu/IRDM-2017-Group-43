# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib_venn

# %%
ori_train = pd.read_csv('/Users/osx/Desktop/web-datamining/IRDM/Data/train.csv',encoding = "ISO-8859-1")
ori_test = pd.read_csv('/Users/osx/Desktop/web-datamining/IRDM/Data/test.csv',encoding = "ISO-8859-1")
ori_attributes = pd.read_csv('/Users/osx/Desktop/web-datamining/IRDM/Data/attributes.csv', encoding="ISO-8859-1")
ori_pro_descr = pd.read_csv('/Users/osx/Desktop/web-datamining/IRDM/Data/product_descriptions.csv')

# %%
train_productid =ori_train['product_uid'].unique()
test_productid =ori_test['product_uid'].unique()
attr_productid =ori_attributes['product_uid'].unique()

# %%
set1 = set(train_productid)
set2 = set(test_productid)
# set3 = set(ori_attributes)
 
venn2([set1, set2], ('train_productid', 'test_productid'))

plt.title("product_id_intersect")
plt.annotate('Unknown set', xy=v.get_label_by_id('100').get_position() - np.array([0, 10]), xytext=(-70,-70),
             ha='center', textcoords='offset points', bbox=dict(boxstyle='round,pad=0.5', fc='gray', alpha=0.1),
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5',color='gray'))
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.xticks([1,1.25,1.33,1.5,1.67,1.75,2,2.25,2.33,2.5,2.67,2.75,3])
plt.bar(ori_train.relevance.value_counts().index,ori_train.relevance.value_counts().values,\
         alpha=0.7,align="center", width = 1/24)
plt.title('relevence score distribution for the train set')
plt.xlabel('relevance score')
plt.ylabel('row count')
plt.show()
